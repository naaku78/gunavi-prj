# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pprint 
import os

# %%
key = os.environ.get('COINMARKETCAP_API_KEY')

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
# Enter period to validate performance
url = f'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
print(url)
headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': key,
}
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'

}

session = Session()
session.headers.update(headers)
try:
    response = session.get(url)
    data = json.loads(response.text)
    pp.pprint(data)
    

except (ConnectionError, Timeout, TooManyRedirects) as e:
    data = json.loads(response.text)
    pp.pprint(data)
# Out:
# https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest
# {   'data': [   {   'circulating_supply': 4228,
#                     'cmc_rank': 3464,
#                     'date_added': '2022-04-22T00:50:48.789Z',
#                     'id': 8531,
#                     'last_updated': '2022-04-22T00:50:48.789Z',
#                     'max_supply': 7964,
#                     'name': '3n519ytdtqr',
#                     'num_market_pairs': 5310,
#                     'platform': None,
#                     'quote': {   'BTC': {   'fully_diluted_market_cap': 0.30669063954788545,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 7561,
#                                             'market_cap_dominance': 98,
#                                             'percent_change_1h': None,
#                                             'percent_change_24h': None,
#                                             'percent_change_7d': None,
#                                             'price': 1471,
#                                             'volume_24h': 7848,
#                                             'volume_change_24h': None},
#                                  'USD': {   'fully_diluted_market_cap': 0.27210633886984437,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 0.8010762822980226,
#                                             'market_cap_dominance': 8809,
#                                             'percent_change_1h': 0.13191334495267615,
#                                             'percent_change_24h': 0.40246705324137944,
#                                             'percent_change_7d': 0.2619979408908182,
#                                             'price': 0.7050464336301838,
#                                             'volume_24h': 4044,
#                                             'volume_change_24h': 0.0683107089817685}},
#                     'self_reported_circulating_supply': None,
#                     'self_reported_market_cap': None,
#                     'slug': 'xsxrprjcqkc',
#                     'symbol': '2qix68o4cgf',
#                     'tags': [   'dza6fvnjx3',
#                                 'eb15zx63hwd',
#                                 'l76zhti0at',
#                                 'bvwgt2k6yw5',
#                                 'w3vnesv8nf',
#                                 'lqz8qhkhvwk',
#                                 '0949feoa96qi',
#                                 'tvb2o3l1ea',
#                                 'pwj0zlt0doj',
#                                 '61s0l6iqkds'],
#                     'total_supply': 3002},
#                 {   'circulating_supply': 1065,
#                     'cmc_rank': 420,
#                     'date_added': '2022-04-22T00:50:48.789Z',
#                     'id': 2143,
#                     'last_updated': '2022-04-22T00:50:48.789Z',
#                     'max_supply': 4495,
#                     'name': '3zw67mg9pae',
#                     'num_market_pairs': 7464,
#                     'platform': None,
#                     'quote': {   'BTC': {   'fully_diluted_market_cap': 0.6273643550371135,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 6390,
#                                             'market_cap_dominance': 6514,
#                                             'percent_change_1h': None,
#                                             'percent_change_24h': None,
#                                             'percent_change_7d': None,
#                                             'price': 5663,
#                                             'volume_24h': 3216,
#                                             'volume_change_24h': None},
#                                  'USD': {   'fully_diluted_market_cap': 0.626130736133548,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 0.7331945909477631,
#                                             'market_cap_dominance': 3385,
#                                             'percent_change_1h': 0.9673079328221721,
#                                             'percent_change_24h': 0.2585742685118204,
#                                             'percent_change_7d': 0.9819307694253341,
#                                             'price': 0.9557528191632294,
#                                             'volume_24h': 4963,
#                                             'volume_change_24h': 0.5976038069302914}},
#                     'self_reported_circulating_supply': None,
#                     'self_reported_market_cap': None,
#                     'slug': 'wgranp67euf',
#                     'symbol': 'qbds4oly0aq',
#                     'tags': [   'v06mvokdl7',
#                                 'hwre102anro',
#                                 '0qldswxf5rv',
#                                 'tdoiz5cin',
#                                 '6jniggctb7m',
#                                 'ct9lrxshnp7',
#                                 '92xh4guhmhp',
#                                 '0vtty4qus7vj',
#                                 '9b2ne21ksy',
#                                 '15e7kff5gzw'],
#                     'total_supply': 2056},
#                 {   'circulating_supply': 3351,
#                     'cmc_rank': 7050,
#                     'date_added': '2022-04-22T00:50:48.789Z',
#                     'id': 6053,
#                     'last_updated': '2022-04-22T00:50:48.789Z',
#                     'max_supply': 4151,
#                     'name': '7fn5vi7xlp3',
#                     'num_market_pairs': 9906,
#                     'platform': None,
#                     'quote': {   'BTC': {   'fully_diluted_market_cap': 0.2753300429342038,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 5161,
#                                             'market_cap_dominance': 601,
#                                             'percent_change_1h': None,
#                                             'percent_change_24h': None,
#                                             'percent_change_7d': None,
#                                             'price': 1337,
#                                             'volume_24h': 7040,
#                                             'volume_change_24h': None},
#                                  'USD': {   'fully_diluted_market_cap': 0.09691689917968094,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 0.5927520327170368,
#                                             'market_cap_dominance': 4347,
#                                             'percent_change_1h': 0.7167039560453299,
#                                             'percent_change_24h': 0.8196816236122471,
#                                             'percent_change_7d': 0.21869389029449904,
#                                             'price': 0.6568594316215077,
#                                             'volume_24h': 5332,
#                                             'volume_change_24h': 0.7106124857935205}},
#                     'self_reported_circulating_supply': None,
#                     'self_reported_market_cap': None,
#                     'slug': 'opndhqx9d9',
#                     'symbol': 'svgthve7kh',
#                     'tags': [   'qe9ptgzito',
#                                 '0lmxslulzwy',
#                                 'khi69nb0rhp',
#                                 'ffergapjq6u',
#                                 'b2a5x4mlrzr',
#                                 '4mi1s6ms0v',
#                                 '14uddrh70er',
#                                 'qsqcoyzx3ci',
#                                 '0ectxc71hjlj',
#                                 'vuq2h1cqlop'],
#                     'total_supply': 2221},
#                 {   'circulating_supply': 4838,
#                     'cmc_rank': 1867,
#                     'date_added': '2022-04-22T00:50:48.789Z',
#                     'id': 4625,
#                     'last_updated': '2022-04-22T00:50:48.789Z',
#                     'max_supply': 9153,
#                     'name': 'km5k5l3zz3',
#                     'num_market_pairs': 2616,
#                     'platform': None,
#                     'quote': {   'BTC': {   'fully_diluted_market_cap': 0.8268606414114432,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 5425,
#                                             'market_cap_dominance': 5173,
#                                             'percent_change_1h': None,
#                                             'percent_change_24h': None,
#                                             'percent_change_7d': None,
#                                             'price': 3909,
#                                             'volume_24h': 3706,
#                                             'volume_change_24h': None},
#                                  'USD': {   'fully_diluted_market_cap': 0.5062590787353101,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 0.16828905539113626,
#                                             'market_cap_dominance': 3738,
#                                             'percent_change_1h': 0.1329152307523911,
#                                             'percent_change_24h': 0.43653164999594396,
#                                             'percent_change_7d': 0.6807086335120365,
#                                             'price': 0.10202319468129106,
#                                             'volume_24h': 3103,
#                                             'volume_change_24h': 0.66389584379197}},
#                     'self_reported_circulating_supply': None,
#                     'self_reported_market_cap': None,
#                     'slug': '5pu2w0gxbhc',
#                     'symbol': 'o3uofcj4nan',
#                     'tags': [   'zq5gprke7w',
#                                 'xy5i8g8v0qh',
#                                 'oenf9xlivjd',
#                                 'zy43yyes96',
#                                 'boc0ex8the',
#                                 'aoae3tuc7a5',
#                                 'px3fnob73b9',
#                                 '75hxccq9vo2',
#                                 'dpha4933dc8',
#                                 'xcqvwxcabxc'],
#                     'total_supply': 6030},
#                 {   'circulating_supply': 7398,
#                     'cmc_rank': 244,
#                     'date_added': '2022-04-22T00:50:48.789Z',
#                     'id': 4877,
#                     'last_updated': '2022-04-22T00:50:48.789Z',
#                     'max_supply': 5272,
#                     'name': 'iylot8ccf4',
#                     'num_market_pairs': 2170,
#                     'platform': None,
#                     'quote': {   'BTC': {   'fully_diluted_market_cap': 0.0017505644424256062,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 511,
#                                             'market_cap_dominance': 7574,
#                                             'percent_change_1h': None,
#                                             'percent_change_24h': None,
#                                             'percent_change_7d': None,
#                                             'price': 7196,
#                                             'volume_24h': 7768,
#                                             'volume_change_24h': None},
#                                  'USD': {   'fully_diluted_market_cap': 0.3076657255368347,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 0.7099271609141755,
#                                             'market_cap_dominance': 8197,
#                                             'percent_change_1h': 0.1270195658364044,
#                                             'percent_change_24h': 0.06872192068036065,
#                                             'percent_change_7d': 0.05272796583463979,
#                                             'price': 0.24929051398438773,
#                                             'volume_24h': 386,
#                                             'volume_change_24h': 0.44519260888394796}},
#                     'self_reported_circulating_supply': None,
#                     'self_reported_market_cap': None,
#                     'slug': 'g3vmol99wmd',
#                     'symbol': 'qqbcwamlyii',
#                     'tags': [   '2dty0237de6',
#                                 'qavg3uur0ge',
#                                 '84hnutidi5d',
#                                 'n9hztth1tpd',
#                                 'tq1ariwwal',
#                                 'hdzi8ddpk0r',
#                                 '3dcwxxtip5y',
#                                 'q7y8d7u0daj',
#                                 'mgrsn776ytj',
#                                 'rwmvok7yeyf'],
#                     'total_supply': 1553},
#                 {   'circulating_supply': 4459,
#                     'cmc_rank': 4487,
#                     'date_added': '2022-04-22T00:50:48.789Z',
#                     'id': 822,
#                     'last_updated': '2022-04-22T00:50:48.789Z',
#                     'max_supply': 7685,
#                     'name': 'lfqqzlmir0q',
#                     'num_market_pairs': 6597,
#                     'platform': None,
#                     'quote': {   'BTC': {   'fully_diluted_market_cap': 0.7044642483330941,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 355,
#                                             'market_cap_dominance': 8149,
#                                             'percent_change_1h': None,
#                                             'percent_change_24h': None,
#                                             'percent_change_7d': None,
#                                             'price': 9149,
#                                             'volume_24h': 3329,
#                                             'volume_change_24h': None},
#                                  'USD': {   'fully_diluted_market_cap': 0.1016678325843936,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 0.08285552074307168,
#                                             'market_cap_dominance': 5906,
#                                             'percent_change_1h': 0.39813763808657976,
#                                             'percent_change_24h': 0.35323209992640203,
#                                             'percent_change_7d': 0.20572472138756726,
#                                             'price': 0.7714235122028408,
#                                             'volume_24h': 3422,
#                                             'volume_change_24h': 0.6290774586992858}},
#                     'self_reported_circulating_supply': None,
#                     'self_reported_market_cap': None,
#                     'slug': 'r53se8u0sip',
#                     'symbol': 'yb0icqyryma',
#                     'tags': [   '05lqjaajv7ut',
#                                 '62liilnb11q',
#                                 'gzulmfucukv',
#                                 'fcsyar4fynr',
#                                 'f2un77dzr2',
#                                 'i1fseodxc9i',
#                                 '0l8af429xq',
#                                 'jn3asdo0uob',
#                                 'uzmymhwopy',
#                                 'f1oy200wwpa'],
#                     'total_supply': 4894},
#                 {   'circulating_supply': 9678,
#                     'cmc_rank': 8969,
#                     'date_added': '2022-04-22T00:50:48.789Z',
#                     'id': 7602,
#                     'last_updated': '2022-04-22T00:50:48.789Z',
#                     'max_supply': 5294,
#                     'name': '846aqqbsq4j',
#                     'num_market_pairs': 8262,
#                     'platform': None,
#                     'quote': {   'BTC': {   'fully_diluted_market_cap': 0.41210576573676994,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 9746,
#                                             'market_cap_dominance': 1608,
#                                             'percent_change_1h': None,
#                                             'percent_change_24h': None,
#                                             'percent_change_7d': None,
#                                             'price': 5952,
#                                             'volume_24h': 6012,
#                                             'volume_change_24h': None},
#                                  'USD': {   'fully_diluted_market_cap': 0.03333614188248801,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 0.46757155033342057,
#                                             'market_cap_dominance': 6745,
#                                             'percent_change_1h': 0.09605656763878256,
#                                             'percent_change_24h': 0.7023099702671056,
#                                             'percent_change_7d': 0.7144200940271501,
#                                             'price': 0.1057614830273581,
#                                             'volume_24h': 3730,
#                                             'volume_change_24h': 0.6392247564177849}},
#                     'self_reported_circulating_supply': None,
#                     'self_reported_market_cap': None,
#                     'slug': 'j6frt5j5v4',
#                     'symbol': 'bqtodwh6ia',
#                     'tags': [   'jsq50hatlc',
#                                 '0fz7rg1nwdqg',
#                                 'kqjhgnwm83q',
#                                 '2lmzdit8bp6',
#                                 '1g13rhkopy9',
#                                 '01e0g6yuh3pf',
#                                 'jj6o5zz3ti',
#                                 'xhu9oungwi',
#                                 '3itooj5gjjk',
#                                 'm5anwvygmje'],
#                     'total_supply': 412},
#                 {   'circulating_supply': 4944,
#                     'cmc_rank': 612,
#                     'date_added': '2022-04-22T00:50:48.789Z',
#                     'id': 2432,
#                     'last_updated': '2022-04-22T00:50:48.789Z',
#                     'max_supply': 6414,
#                     'name': 'w5tvru9ncfn',
#                     'num_market_pairs': 4011,
#                     'platform': None,
#                     'quote': {   'BTC': {   'fully_diluted_market_cap': 0.9544059089019488,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 1376,
#                                             'market_cap_dominance': 8654,
#                                             'percent_change_1h': None,
#                                             'percent_change_24h': None,
#                                             'percent_change_7d': None,
#                                             'price': 2614,
#                                             'volume_24h': 3902,
#                                             'volume_change_24h': None},
#                                  'USD': {   'fully_diluted_market_cap': 0.7299463452177373,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 0.05103920752807478,
#                                             'market_cap_dominance': 6147,
#                                             'percent_change_1h': 0.6411943230906574,
#                                             'percent_change_24h': 0.9929790225016026,
#                                             'percent_change_7d': 0.08083382931223704,
#                                             'price': 0.7080969723602968,
#                                             'volume_24h': 9358,
#                                             'volume_change_24h': 0.6238952602281866}},
#                     'self_reported_circulating_supply': None,
#                     'self_reported_market_cap': None,
#                     'slug': '07l4n76rqvxx',
#                     'symbol': '4jyyh62dw1w',
#                     'tags': [   'f4oyrehy03q',
#                                 'urcpnz4os4',
#                                 'mbbvabwul2',
#                                 'ecilflu7c9n',
#                                 '6o7tatqjskp',
#                                 '07bvrr0fll8f',
#                                 'dtfrdmkjlrc',
#                                 '7eif1ango5f',
#                                 'vsw0ghznn8a',
#                                 'q6o3et6ynd'],
#                     'total_supply': 1005},
#                 {   'circulating_supply': 2052,
#                     'cmc_rank': 825,
#                     'date_added': '2022-04-22T00:50:48.789Z',
#                     'id': 3793,
#                     'last_updated': '2022-04-22T00:50:48.789Z',
#                     'max_supply': 4122,
#                     'name': 'lkemi5ud8bq',
#                     'num_market_pairs': 6694,
#                     'platform': None,
#                     'quote': {   'BTC': {   'fully_diluted_market_cap': 0.6974497878902945,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 5653,
#                                             'market_cap_dominance': 9882,
#                                             'percent_change_1h': None,
#                                             'percent_change_24h': None,
#                                             'percent_change_7d': None,
#                                             'price': 182,
#                                             'volume_24h': 2420,
#                                             'volume_change_24h': None},
#                                  'USD': {   'fully_diluted_market_cap': 0.40632133582201946,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 0.9049734391704485,
#                                             'market_cap_dominance': 9029,
#                                             'percent_change_1h': 0.20146482468260607,
#                                             'percent_change_24h': 0.8435463584860297,
#                                             'percent_change_7d': 0.3676849278881411,
#                                             'price': 0.753383929740217,
#                                             'volume_24h': 1112,
#                                             'volume_change_24h': 0.372255148325235}},
#                     'self_reported_circulating_supply': None,
#                     'self_reported_market_cap': None,
#                     'slug': 'd051e7huz99',
#                     'symbol': '9nhd9t8hard',
#                     'tags': [   '7nzm17wo0n9',
#                                 'ay1kzzzd6yw',
#                                 'ey1uhxpta8d',
#                                 'nu981qtrdm8',
#                                 'wwcgmihmdh',
#                                 'f7ma3rqeqoc',
#                                 'haf5lya5sl',
#                                 'pfs25b847xl',
#                                 'dvf8r86lir',
#                                 'ubzazazq4zs'],
#                     'total_supply': 3091},
#                 {   'circulating_supply': 3039,
#                     'cmc_rank': 9472,
#                     'date_added': '2022-04-22T00:50:48.789Z',
#                     'id': 8788,
#                     'last_updated': '2022-04-22T00:50:48.789Z',
#                     'max_supply': 9390,
#                     'name': 'scho7a6srx',
#                     'num_market_pairs': 5147,
#                     'platform': None,
#                     'quote': {   'BTC': {   'fully_diluted_market_cap': 0.33810397274144277,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 8042,
#                                             'market_cap_dominance': 1704,
#                                             'percent_change_1h': None,
#                                             'percent_change_24h': None,
#                                             'percent_change_7d': None,
#                                             'price': 4638,
#                                             'volume_24h': 3901,
#                                             'volume_change_24h': None},
#                                  'USD': {   'fully_diluted_market_cap': 0.05398865674906994,
#                                             'last_updated': '2022-04-22T00:50:48.789Z',
#                                             'market_cap': 0.5156149257635512,
#                                             'market_cap_dominance': 1393,
#                                             'percent_change_1h': 0.8158677691282248,
#                                             'percent_change_24h': 0.9294801086326809,
#                                             'percent_change_7d': 0.0908731419726061,
#                                             'price': 0.06306223699909519,
#                                             'volume_24h': 3076,
#                                             'volume_change_24h': 0.481454390032541}},
#                     'self_reported_circulating_supply': None,
#                     'self_reported_market_cap': None,
#                     'slug': '6srxjzaqd8p',
#                     'symbol': '73j5xuc183e',
#                     'tags': [   'o1m2brspbsj',
#                                 'r4y3jvgszi',
#                                 '8aztigkgc05',
#                                 'xd4xycpxak',
#                                 'y5wqf6xho8',
#                                 'tyotpjio3cd',
#                                 'ttgfoxg8rvc',
#                                 'x3amxlr6qdb',
#                                 'vl0mdva6b4d',
#                                 'kln97dsuh4'],
#                     'total_supply': 4559}],
#     'status': {   'credit_count': 1,
#                   'elapsed': 1,
#                   'error_code': 0,
#                   'error_message': None,
#                   'notice': None,
#                   'timestamp': '2022-04-22T00:50:48.789Z'}}

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2022-04-22T00:19:32.358Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 9589, 'name': '2dnhbrmxo2a', 'symbol': 'leyf861wkt', 'slug': 'zhexq3msnmo', 'cmc_rank': 3443, 'num_market_pairs': 8164, 'circulating_supply': 4401, 'total_supply': 2442, 'max_supply': 1817, 'last_updated': '2022-04-22T00:19:32.358Z', 'date_added': '2022-04-22T00:19:32.358Z', 'tags': ['qm85lolcoz', 'tew6v8wajcj', 'xanjt2by1n', 'b0j541a15u4', 'y2ypr27cq1', 'u3fx6itcxi', 'rgj6chhp7xd', '4ji48li4skx', 'khd8pyjzkpc', 'kunooqxw14t'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.07488549817144241, 'volume_24h': 8856, 'volume_change_24h': 0.2591070773868398, 'percent_change_1h': 0.392976613928953, 'percent_change_24h': 0.5412097779378711, 'percent_change_7d': 0.9646480199407945, 'market_cap': 0.9330031362603697, 'market_cap_dominance': 7060, 'fully_diluted_market_cap': 0.4595332367945062, 'last_updated': '2022-04-22T00:19:32.358Z'}}}, {'id': 1839, 'name': 'rbml7pss1ms', 'symbol': 'rvhwh2rwdzq', 'slug': '89mrpnz29w5', 'cmc_rank': 6765, 'num_market_pairs': 9127, 'circulating_supply': 1266, 'total_supply': 7629, 'max_supply': 9304, 'last_updated': '2022-04-22T00:19:32.358Z', 'date_added': '2022-04-22T00:19:32.358Z', 'tags': ['tsrsasrdpri', 'y9z6atl942a', 't7pl3pavghn', 'c1mgbm47wm9', 'q21fl4rtun', '3oyfc6xyg6e', '5h4i1q4atrm', 'ik2k35vbls', 'byzldjd9snv', 'hj4jo29g29r'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5659734874120452, 'volume_24h': 7834, 'volume_change_24h': 0.681729789340159, 'percent_change_1h': 0.6292832824645773, 'percent_change_24h': 0.8695695181404384, 'percent_change_7d': 0.5063815108272118, 'market_cap': 0.9606536230192453, 'market_cap_dominance': 3303, 'fully_diluted_market_cap': 0.5592547870697893, 'last_updated': '2022-04-22T00:19:32.358Z'}}}, {'id': 6431, 'name': '6au7x94yhmg', 'symbol': 'meo5r2v69ag', 'slug': 'j29gyycn8qg', 'cmc_rank': 1462, 'num_market_pairs': 7615, 'circulating_supply': 5379, 'total_supply': 6353, 'max_supply': 6090, 'last_updated': '2022-04-22T00:19:32.358Z', 'date_added': '2022-04-22T00:19:32.358Z', 'tags': ['rea8ocvaxq', 'ea7moojcfdg', 'fs997euh0ue', 's66t1ixhv1a', 'zi3aoc1ajm', 'j1s8yyifb2', 'v5x1gw6hvy', '05g8u8socu8d', 'cqj05btoj4e', 'tpwu0zy9jhe'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.15723224055163265, 'volume_24h': 9818, 'volume_change_24h': 0.8216975933228734, 'percent_change_1h': 0.37896672263890796, 'percent_change_24h': 0.9258429251447324, 'percent_change_7d': 0.4681558589776804, 'market_cap': 0.31096945203712467, 'market_cap_dominance': 8647, 'fully_diluted_market_cap': 0.39557230088259665, 'last_updated': '2022-04-22T00:19:32.358Z'}}}, {'id': 5307, 'name': 'r9pyg12mwcr', 'symbol': 'hr5nl4da2tp', 'slug': 'fgru7rik2ia', 'cmc_rank': 8632, 'num_market_pairs': 9388, 'circulating_supply': 9729, 'total_supply': 1255, 'max_supply': 5856, 'last_updated': '2022-04-22T00:19:32.358Z', 'date_added': '2022-04-22T00:19:32.358Z', 'tags': ['uulla4xebqd', 'p68qvndpix', 'bodvjac2vmh', 'dwbp1hjoedo', 'kzg0dthbm4p', 'yfiju52f338', 'pf7kyesvnp', 'z9n2ez0bqfs', 'vaoct37xe4k', 'myk3ibvkq9m'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6798661741257863, 'volume_24h': 9332, 'volume_change_24h': 0.9554443007727915, 'percent_change_1h': 0.2348171651476454, 'percent_change_24h': 0.35100979419194034, 'percent_change_7d': 0.492827070845846, 'market_cap': 0.4394224097773243, 'market_cap_dominance': 1920, 'fully_diluted_market_cap': 0.8495182507421735, 'last_updated': '2022-04-22T00:19:32.358Z'}}}, {'id': 158, 'name': 'ywiwtc0ayz', 'symbol': '2c2bnx2su9b', 'slug': '89h0dzeajwv', 'cmc_rank': 2939, 'num_market_pairs': 3095, 'circulating_su ...
